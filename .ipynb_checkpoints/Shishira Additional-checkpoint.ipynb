# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension
pn.extension('tabulator')

import hvplot.pandas
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')

import matplotlib
from datetime import date
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
#read Excel sheet
df_hosp = pd.read_excel('HospitalDatabase.xlsx',sheet_name = None)

#initializing variables for each sheet in the excel file
pats = df_hosp['Patients']
ed_visits = df_hosp['EDVisits']
amb_visits = df_hosp['AmbulatoryVisits']
re_adm = df_hosp['ReAdmissionRegistry']
discharges = df_hosp['Discharges']
providers = df_hosp['Providers']
ed_unique = df_hosp['EDUnique']

# %%
provider_deets = providers
provider_deets['YearsOfExperience'] = date.today().year - providers['ProviderDateOnStaff'].dt.year
provider_deets['DateOnStaff'] = providers['ProviderDateOnStaff'].dt.date
provider_deets = provider_deets[['ProviderID','ProviderName','ProviderSpecialty','YearsOfExperience','DateOnStaff']]
provider_deets
# Out:
#     ProviderID     ProviderName ProviderSpecialty  YearsOfExperience  \
# 0            1        Sally Sue        Pediatrics                 30
# 1            2       Mike Myers        Pediatrics                 30
# 2            3   Jordan Michael        Pediatrics                 30
# 3            4        Ted Texas        Pediatrics                 30
# 4            5         Ala Bama        Pediatrics                 28
# 5            6       Harry Kane        Pediatrics                 28
# 6            7        Barry Bar        Pediatrics                 28
# 7            8        Ted Green        Pediatrics                 27
# 8            9        Ted Black        Pediatrics                 26
# 9           10         Fred Man           Surgery                 25
# 10          11     Kim Kimberly           Surgery                 25
# 11          12         Sarah Ab           Surgery                 25
# 12          13  Abigail Marriot           Surgery                 25
# 13          14          Dave Yu           Surgery                 24
# 14          15  Christian Saint           Surgery                 23
# 15          16     Perry Pardon           Surgery                 22
# 16          17     Kent Kendall        Cardiology                 22
# 17          18       Ryan Kevin        Cardiology                 20
# 18          19     Tyler Conner        Cardiology                 20
# 19          20    Bailey Barret        Cardiology                 20
# 20          21      Megan Bonco        Cardiology                 19
# 21          22    Joesph Walter        Cardiology                 18
# 22          23      Walter King        Cardiology                 17
# 23          24        Luke Long        Cardiology                 17
# 24          25      Justin Time       PrimaryCare                 17
# 25          26      Mike Joseph       PrimaryCare                 17
# 26          27   Bridget Brenda       PrimaryCare                 16
# 27          28      Brenda Bing       PrimaryCare                 16
# 28          29    Chandler Bing       PrimaryCare                 16
# 29          30      Joesph Ross       PrimaryCare                 15
# 30          31     Dwight Scott       PrimaryCare                 14
# 31          32  Michael Halpert       PrimaryCare                 14
# 32          33      Pamela Ding       PrimaryCare                 14
# 33          34       Tony Creed       PrimaryCare                 13
# 34          35  Phyllis Stanley       PrimaryCare                 12
# 35          36        Holly Hue       PrimaryCare                 11
# 36          37        Trent Tye       PrimaryCare                 10
# 37          38    Kimberly Cone       PrimaryCare                 10
# 38          39       Harry West       PrimaryCare                 10
# 39          40     Rosie Renter       PrimaryCare                 10
#
#    DateOnStaff
# 0   1993-01-01
# 1   1993-05-02
# 2   1993-06-24
# 3   1993-12-23
# 4   1995-01-10
# 5   1995-07-21
# 6   1995-11-21
# 7   1996-05-30
# 8   1997-02-20
# 9   1998-03-17
# 10  1998-05-10
# 11  1998-08-18
# 12  1998-11-08
# 13  1999-06-26
# 14  2000-08-27
# 15  2001-02-13
# 16  2001-12-22
# 17  2003-01-14
# 18  2003-07-09
# 19  2003-08-20
# 20  2004-02-17
# 21  2005-02-04
# 22  2006-03-12
# 23  2006-04-28
# 24  2006-06-21
# 25  2006-12-29
# 26  2007-06-30
# 27  2007-11-18
# 28  2007-12-07
# 29  2008-11-08
# 30  2009-04-18
# 31  2009-09-02
# 32  2009-11-12
# 33  2010-04-28
# 34  2011-05-05
# 35  2012-06-24
# 36  2013-01-12
# 37  2013-05-23
# 38  2013-07-14
# 39  2013-09-11

# %%
idf = provider_deets.interactive()
pn.extension()

select_specialty = pn.widgets.Select(name='Provider Specialty', options=provider_deets['ProviderSpecialty'].unique().tolist(), width=150)
#provider_count = pn.widgets.StaticText(value=select_specialty.value)

pn.Column(select_specialty)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Column
#     [0] Select(name='Provider Specialty', options=['Pediatrics', ...], value='Pediatrics', width=150)

# %%
idf_provider = idf[(idf.ProviderSpecialty == select_specialty)]
provider_pipeline = idf_provider.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width')

provider_pipeline
# Out:
# <div id='f614b1f0-0d09-4b0d-8a99-921311b4e653'>
#   <div id="b1170196-9c68-4d28-a2d1-4fa3a21022c7" data-root-id="f614b1f0-0d09-4b0d-8a99-921311b4e653" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"15eda43c-2acb-45d1-b306-a752ee5cbbf1":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"Row","id":"f614b1f0-0d09-4b0d-8a99-921311b4e653","attributes":{"name":"Row15442","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"7aef4514-959a-4100-a1b7-f984acde7184","attributes":{"url":"https://cdn.holoviz.org/panel/1.1.0/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"09734953-a817-4f0c-8fe9-84c090ab2853","attributes":{"url":"https://cdn.holoviz.org/panel/1.1.0/dist/css ...

# %%
idf_amb_visits = amb_visits.interactive()
patients_provider = idf_provider.merge(idf_amb_visits, how='inner', on='ProviderID')
 
#matplotlib.rc('xtick', labelsize=7) 
#matplotlib.rc('ytick', labelsize=8)

provider_patient_count = patients_provider.groupby(['ProviderName']).size().plot(kind='bar', color='PURPLE', 
    xlabel='Patient Count', ylabel='Provider Name', title='Patients count per Provider')

provider_patient_count
# Out:
# <div id='1ad58451-fb6d-429d-875a-30e78f96495e'>
#   <div id="c51583ea-d69c-4a3d-8ca2-3c97f96019e5" data-root-id="1ad58451-fb6d-429d-875a-30e78f96495e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e9fd13f4-0133-48e4-88eb-b0a272405f71":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"Row","id":"1ad58451-fb6d-429d-875a-30e78f96495e","attributes":{"name":"Row14633","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"a1c1b391-4691-45e8-9f6b-9b424c03969e","attributes":{"url":"https://cdn.holoviz.org/panel/1.1.0/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"0fcf98ca-aa2b-4525-979c-81a162dc0947","attributes":{"url":"https://cdn.holoviz.org/panel/1.1.0/dist/css ...

# %%
template = pn.template.FastListTemplate(
    title='PROVIDERS',
    sidebar=[pn.pane.Markdown("## Provider Details"),select_specialty],
    main=[pn.Row(pn.Column(provider_pipeline.panel(width=600))),
    pn.Row(pn.Column(provider_patient_count.panel(width=600), margin=(0,25)))],
    accent_base_color="#A01346",header_background="#88d8b0"
)
template.show()
# Out:
# Launching server at http://localhost:59330
