# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_hosp = pd.read_excel('HospitalDatabase.xlsx',sheet_name = None)

# %% [markdown]
# # 21. Find reasonForVisit with highest count of acuity 5 patients.

# %%
filtered_df_hosp = df_hosp['EDVisits'].query("Acuity == 5")
print(filtered_df_hosp['ReasonForVisit'].value_counts().idxmax() + ' with ' + str(filtered_df_hosp['ReasonForVisit'].value_counts().max()) + ' visits.')
# Out:
# Chest Pain with 61 visits.

# %% [markdown]
# # 22. Find the visit type with maximum 'No Show'.

# %%
filtered_df_hosp = df_hosp['AmbulatoryVisits'].query("VisitStatus == 'No Show'")
print(filtered_df_hosp['VisitType'].value_counts().idxmax() + " with " + str(filtered_df_hosp['VisitType'].value_counts().max()) + " No Show(s).")
# Out:
# Telemedicine with 74 No Show(s).

# %% [markdown]
# # 23. Get the list of patient ID's which are not there in ReadmissionRegistry.

# %%
filtered_df_hosp = df_hosp['Patients'][~df_hosp['Patients'].PatientID.isin(df_hosp['ReAdmissionRegistry']['PatientID'].unique())]
print("Patient IDs not in ReAdmission Registry are:")
print([filtered_df_hosp['PatientID'].to_string(index = False).replace("\n", " ").strip()])
# Out:
# Patient IDs not in ReAdmission Registry are:
# ['  4 135 145 189 200 224 234 374 378 379 380 381 382 383 384 385 386 387 388 389 390 391 392 393 394 395 396 397 398 399 414 501 562 599 690 691 704 726 743 744 745 746 747 748 749 750 751 752 753 754 755 756 757 758 759 760 761 762 763 764 765 766 767 768 769 770 771 772 773 774 775 776 777 778 779 780 781 782 783 784 785 786 787 788 789 790 791 792 793 794 795 796 797 798 799 800 801 802 803 804 805 806 807 808 809 810 811 812 813 814 815 816 817 818 819 820 821 822 823 824 825 826 827 828 829 830 831 832 833 834 835 836 837 838 839 840 841 842 843 844 845 846 847 848 849 850 851 852 853 854 855 856 857 858 859 860 861 862 863 864 865 866 867 868 869 870 871 872 873 874 875 876 877 878 879 880 881 882 883 884 885 886 887 888 889 890 891 892 893 894 895 896 897 898 899 900 901 902 903 904 905 906 907 908 909 910 911 912 913 914 915 916 917 918 919 920 921 922 923 924 925 926 927 928 929 930 931 932 933 934 935 936 937 938 939 940 941 942 943 944 945']

# %% [markdown]
# # 24. Get the number of patients based on ReasonForVisit and EDDisposition (use stack/unstack functions).

# %%
subset_df_hosp = df_hosp['EDVisits'][['EDDisposition', 'ReasonForVisit']]
print(subset_df_hosp.value_counts())
df = subset_df_hosp.stack()
#df.value_counts()
print(df)
#print(filtered_df_hosp[['Race', 'Gender']].value_counts())
# Out:
# EDDisposition  ReasonForVisit
# Discharged     Fever                  188
#                Stomach Ache           154
# Admitted       Pneumonia              136
# Discharged     Migraine               109
# Admitted       Chest Pain              94
# Discharged     Shortness of Breath     77
# Admitted       Shortness of Breath     72
# Discharged     Pneumonia               65
# Admitted       Migraine                47
#                Fever                   46
#                Accident                39
#                Stomach Ache            32
# Discharged     Intoxication            30
#                Laceration              30
# Admitted       Car Accident            17
#                Bleeding                16
#                Gun Shot                16
# Discharged     Chest Pain              15
#                Bleeding                15
#                Cough                    1
# dtype: int64
# 0     EDDisposition         Admitted
#       ReasonForVisit    Stomach Ache
# 1     EDDisposition         Admitted
#       ReasonForVisit        Migraine
# 2     EDDisposition         Admitted
#                             ...
# 1196  ReasonForVisit       Pneumonia
# 1197  EDDisposition       Discharged
#       ReasonForVisit       Pneumonia
# 1198  EDDisposition       Discharged
#       ReasonForVisit       Pneumonia
# Length: 2398, dtype: object

# %% [markdown]
# # 25.Using a bar chart, which Service had the lowest count of Expected Mortality?

# %%
expected_mortality_count = df_hosp['ReAdmissionRegistry'].groupby(['Service'])['ExpectedMortality'].sum().sort_values(ascending = False)
sequential_palette = sns.color_palette("nipy_spectral", len(expected_mortality_count))
plt.figure(figsize = (6, 4))
expected_mortality_count.plot(kind='barh', color = sequential_palette)
plt.title("Total Expected Mortality per Services")
plt.xlabel('Expected Mortality')
# Out:
# Text(0.5, 0, 'Expected Mortality')

# %% [markdown]
# # 26. Using arrays and loops, find the count of patients based on gender.

# %%
pat = df_hosp['Patients']
male_count = 0
female_count = 0
others = 0
for row in range(0, len(pat)-1):
    if pat.loc[row, 'Gender'] == 'Male':
        male_count += 1
    elif pat.loc[row, 'Gender'] == 'Female':
        female_count += 1
    else:
        others += 1
print(f"Male Patients: {male_count}\nFemale Patients: {female_count}\nOthers: {others}")
# Out:
# Male Patients: 536
# Female Patients: 408
# Others: 0

# %% [markdown]
# # 27. Which demographic patients are prone to get stroke?

# %%
# From ReAdmissionRegistry table
filtered_df_hosp = df_hosp['ReAdmissionRegistry'][df_hosp['ReAdmissionRegistry']['PrimaryDiagnosis'] == "Stroke"]
filtered_df_hosp = df_hosp['Patients'][(df_hosp['Patients'].PatientID.isin(filtered_df_hosp.PatientID))]
print(filtered_df_hosp["Race"].value_counts().idxmax() + "s are more prone to get Stroke")
# Out:
# Black/African-Americans are more prone to get Stroke

# %%
# From Discharges table
filtered_df_hosp = df_hosp['Discharges'][df_hosp['Discharges']['PrimaryDiagnosis'] == "Stroke"]
filtered_df_hosp = df_hosp['Patients'][(df_hosp['Patients'].PatientID.isin(filtered_df_hosp.PatientID))]
print(filtered_df_hosp["Race"].value_counts().idxmax() + "s are more prone to get Stroke")
# Out:
# Black/African-Americans are more prone to get Stroke

# %% [markdown]
# # 28. Details of the patients whose firstname or lastname contains string "lau" , should be case insensitive.

# %%
df_hosp['Patients'][df_hosp['Patients'].FirstName.str.contains("lau", case=False) | df_hosp['Patients'].LastName.str.contains("lau", case=False)]
# Out:
#      PatientID FirstName   LastName             DateOfBirth  Gender  \
# 282        283    Lauren     Gaskal 1962-05-08 01:54:00.111  Female
# 322        323    Lauren      Foort 1960-06-23 20:07:53.045  Female
# 369        370    Zulauf  Ellingham 1982-12-17 16:27:56.391  Female
# 382        383    Zulauf        LLC 1969-03-16 07:48:49.338  Female
# 454        455    Zulauf      Alvar 1961-10-02 08:24:17.334  Female
# 463        464    Zulauf     Manske 1965-06-22 02:49:28.667  Female
# 818        819    Zulauf   Bitcheno 1967-04-02 07:17:53.635  Female
# 830        831    Zulauf  O'Shavlan 1970-05-17 08:09:28.988  Female
# 850        851     Lemmy    Klausen 1973-06-18 06:19:43.475  Female
# 906        907  Jerrilyn    Klausen 1979-09-04 13:05:57.870    Male
# 910        911    Zulauf     Orbine 1973-06-26 03:13:50.449    Male
#
#                        Race Language
# 282  Black/African-American  English
# 322                   White  English
# 369                   White  English
# 382                   White  English
# 454                   White  English
# 463                   White  English
# 818                   White  English
# 830                   White  English
# 850                   White  English
# 906  Black/African-American  English
# 910  Black/African-American  English

# %% [markdown]
# # 29. Display full name of patients who are born in 1986.

# %%
filtered_df_hosp = df_hosp['Patients'][(df_hosp['Patients'].DateOfBirth.dt.year == 1986)]

#the codes prints in BOLD (begin and end)
print("\033[1m Patients born in 1986:\033[0m")
print(( filtered_df_hosp['FirstName'] + ' ' + filtered_df_hosp['LastName']).to_string(index = False))
# Out:
#  Patients born in 1986:
#     Gabriel  Joseph
#     Lincoln  Brenda
#         Ala Halpert
#        Lolita Darci
#      Fadel Bernardt
#      Bentley Kippax
#         Vale Olanda
#       Britt Dureden
#    Cristabel Chatel
#    Constantia Group
#    Morgan Scrowston
#          Dom Baglow
#     Ignazio Melling
#      Homenick Rings
#        Hashim Slark
#    Ellie Ramsbotham
#     Llewellyn Group
#          Niles Shaw
#          Yvette Inc
#       Siouxie Group
#         Carly Group
#     Worth Pickering
#        Arni Baldack
#    Kuvalis Coupland
# Rebbecca Rollingson
#         Wat Fideler

# %% [markdown]
# # 30.

# %%
for next_dbp in range(1, len(df_hosp['AmbulatoryVisits'])):
    if df_hosp['AmbulatoryVisits']['BloodPressureDiastolic'].loc[0] > df_hosp['AmbulatoryVisits']['BloodPressureDiastolic'].loc[next_dbp]:
        #Swap
        df_hosp['AmbulatoryVisits'].loc[0], df_hosp['AmbulatoryVisits'].loc[next_dbp] = df_hosp['AmbulatoryVisits'].loc[next_dbp], df_hosp['AmbulatoryVisits'].loc[0]

#Print the top most row containing the minimum DBP value        
print(df_hosp['AmbulatoryVisits'].loc[0])
# Out:
# VisitID                                          163
# PatientMRN                                       801
# ProviderID                                        11
# DateofVisit                      2019-02-08 00:00:00
# DateScheduled             2019-02-07 23:41:12.181000
# VisitDepartmentID                                  7
# VisitType                                  Follow Up
# BloodPressureSystolic                          120.0
# BloodPressureDiastolic                     51.695653
# Pulse                                      53.310495
# VisitStatus                                Completed
# Name: 0, dtype: object

# %% [markdown]
# # 31. Find the last name of the patients, by getting the first name from the user.

# %%
print("Enter the patient's First Name: ")
first_name = input()
first_name_matching_row = df_hosp['Patients'][(df_hosp['Patients'].FirstName.str.contains(first_name, case=False))]
print(first_name_matching_row.FirstName + " " + first_name_matching_row.LastName)
# Out:
# Enter the patient's First Name:
#  lanni
# 0         Lanni Sue
# 129    Lanni Angear
# dtype: object

# %% [markdown]
# # 32. Using loc , get the details of the providers where providerId is between 11 and 20 and ProviderSpecialty is Surgery.

# %%
providers = df_hosp['Providers']
print(providers.loc[(providers['ProviderID'].between(11,20)) & (providers['ProviderSpecialty'] == "Surgery")].to_string(index = False))
# Out:
#  ProviderID    ProviderName ProviderSpecialty     ProviderDateOnStaff
#          11    Kim Kimberly           Surgery 1998-05-10 14:47:29.468
#          12        Sarah Ab           Surgery 1998-08-18 05:22:40.762
#          13 Abigail Marriot           Surgery 1998-11-08 12:25:45.705
#          14         Dave Yu           Surgery 1999-06-26 16:18:57.436
#          15 Christian Saint           Surgery 2000-08-27 00:12:40.326
#          16    Perry Pardon           Surgery 2001-02-13 11:49:17.862

# %% [markdown]
# # 33. Which reason of visit has maximum mortality rate.

# %%
joined_df = pd.merge(df_hosp['EDVisits'], df_hosp['ReAdmissionRegistry'], on='PatientID')
reason_mortality = joined_df.groupby('ReasonForVisit')['ExpectedMortality'].sum()
print(f"ReasonOfVisit-{reason_mortality.idxmax()} has the Maximum Mortality Rate of {round(reason_mortality.max(),2)}%")
# Out:
# ReasonOfVisit-Fever has the Maximum Mortality Rate of 64.21%

# %% [markdown]
# # 34. Find the count of White Spanish Male.

# %%
filtered_df_hosp = df_hosp['Patients'][(df_hosp['Patients']['Race'] == 'White') & (df_hosp['Patients']['Gender'] == 'Male') & (df_hosp['Patients']['Language'] == 'Spanish')]
wite_spanish_male_count = filtered_df_hosp[['Race', 'Gender', 'Language']].value_counts().max()
print(f"There are {wite_spanish_male_count} White Spanish Male patients.")
# Out:
# There are 15 White Spanish Male patients.

# %% [markdown]
# # 35. Create a jointplot on expected mortality & expected length of stay.

# %%
# using "ReAdmissionRegistry" Table
sns.jointplot(x=df_hosp['ReAdmissionRegistry']['ExpectedLOS'], y=df_hosp['ReAdmissionRegistry']['ExpectedMortality'], kind="scatter", hue=df_hosp['ReAdmissionRegistry']['ExpectedMortality'])

# %%
# using "Discharges" Table
sns.jointplot(x=df_hosp['Discharges']['ExpectedLOS'], y=df_hosp['Discharges']['ExpectedMortality'], kind="scatter", hue=df_hosp['Discharges']['ExpectedMortality'])

# %% [markdown]
# # 36. Create a heat map on Readmission Registry table to find correlation between columns values.

# %%
df_hosp['ReAdmissionRegistry'][['ExpectedLOS','ExpectedMortality']].style.background_gradient(cmap ='RdYlBu').set_properties(**{'font-size': '20px'})
# Out:
# <style type="text/css">
# #T_1fc7f_row0_col0, #T_1fc7f_row27_col0, #T_1fc7f_row87_col0, #T_1fc7f_row476_col0, #T_1fc7f_row697_col1 {
#   background-color: #fdb567;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row0_col1, #T_1fc7f_row63_col0, #T_1fc7f_row132_col1, #T_1fc7f_row161_col1, #T_1fc7f_row177_col1, #T_1fc7f_row246_col0, #T_1fc7f_row596_col1, #T_1fc7f_row616_col1, #T_1fc7f_row703_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row1_col0, #T_1fc7f_row36_col1, #T_1fc7f_row38_col1, #T_1fc7f_row138_col0, #T_1fc7f_row154_col0, #T_1fc7f_row186_col0, #T_1fc7f_row387_col1, #T_1fc7f_row388_col1, #T_1fc7f_row490_col0, #T_1fc7f_row648_col0, #T_1fc7f_row669_col1 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row1_col1, #T_1fc7f_row231_col1, #T_1fc7f_row296_col0, #T_1fc7f_row454_col0 {
#   background-color: #daf0f6;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row2_col0, #T_1fc7f_row242_col0, #T_1fc7f_row290_col1, #T_1fc7f_row413_col1, #T_1fc7f_row483_col1, #T_1fc7f_row489_col0, #T_1fc7f_row549_col0, #T_1fc7f_row559_col1 {
#   background-color: #d22b27;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row2_col1, #T_1fc7f_row11_col1, #T_1fc7f_row77_col0, #T_1fc7f_row263_col1, #T_1fc7f_row415_col1, #T_1fc7f_row522_col0, #T_1fc7f_row677_col1, #T_1fc7f_row692_col1, #T_1fc7f_row702_col0 {
#   background-color: #fa9857;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row3_col0, #T_1fc7f_row28_col0, #T_1fc7f_row126_col0, #T_1fc7f_row241_col1, #T_1fc7f_row258_col1, #T_1fc7f_row349_col1, #T_1fc7f_row365_col0, #T_1fc7f_row407_col1, #T_1fc7f_row438_col1, #T_1fc7f_row503_col1, #T_1fc7f_row551_col0, #T_1fc7f_row575_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row3_col1, #T_1fc7f_row185_col0, #T_1fc7f_row221_col1, #T_1fc7f_row261_col0, #T_1fc7f_row344_col1, #T_1fc7f_row424_col1, #T_1fc7f_row447_col0, #T_1fc7f_row563_col1 {
#   background-color: #fdb366;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row4_col0, #T_1fc7f_row590_col0, #T_1fc7f_row665_col1 {
#   background-color: #81b7d7;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row4_col1, #T_1fc7f_row19_col0, #T_1fc7f_row51_col0, #T_1fc7f_row168_col1, #T_1fc7f_row214_col0, #T_1fc7f_row236_col0, #T_1fc7f_row292_col0, #T_1fc7f_row506_col1, #T_1fc7f_row620_col0, #T_1fc7f_row662_col1, #T_1fc7f_row685_col0 {
#   background-color: #fee496;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row5_col0, #T_1fc7f_row116_col1, #T_1fc7f_row157_col0, #T_1fc7f_row212_col1, #T_1fc7f_row351_col1, #T_1fc7f_row443_col1, #T_1fc7f_row447_col1, #T_1fc7f_row462_col0, #T_1fc7f_row681_col1 {
#   background-color: #feffc0;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row5_col1, #T_1fc7f_row114_col0, #T_1fc7f_row143_col1, #T_1fc7f_row149_col1, #T_1fc7f_row321_col0, #T_1fc7f_row348_col1, #T_1fc7f_row378_col1, #T_1fc7f_row431_col1, #T_1fc7f_row573_col1, #T_1fc7f_row688_col0 {
#   background-color: #c41e27;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row6_col0, #T_1fc7f_row100_col1, #T_1fc7f_row341_col1 {
#   background-color: #374a9f;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row6_col1, #T_1fc7f_row45_col1, #T_1fc7f_row57_col1, #T_1fc7f_row208_col0, #T_1fc7f_row250_col0, #T_1fc7f_row655_col0, #T_1fc7f_row670_col1 {
#   background-color: #f5fbd2;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row7_col0, #T_1fc7f_row138_col1, #T_1fc7f_row155_col0, #T_1fc7f_row173_col0, #T_1fc7f_row297_col1, #T_1fc7f_row539_col0, #T_1fc7f_row717_col1 {
#   background-color: #fcfec5;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row7_col1, #T_1fc7f_row39_col0, #T_1fc7f_row193_col1, #T_1fc7f_row215_col0, #T_1fc7f_row241_col0, #T_1fc7f_row243_col1, #T_1fc7f_row298_col1, #T_1fc7f_row362_col0, #T_1fc7f_row451_col0, #T_1fc7f_row458_col1, #T_1fc7f_row675_col0 {
#   background-color: #c21c27;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row8_col0, #T_1fc7f_row221_col0, #T_1fc7f_row364_col0, #T_1fc7f_row461_col1, #T_1fc7f_row513_col0 {
#   background-color: #5a8ec1;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row8_col1, #T_1fc7f_row179_col1, #T_1fc7f_row448_col1, #T_1fc7f_row499_col1, #T_1fc7f_row525_col1, #T_1fc7f_row540_col1, #T_1fc7f_row617_col0, #T_1fc7f_row637_col0 {
#   background-color: #d93429;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row9_col0, #T_1fc7f_row26_col1, #T_1fc7f_row119_col0, #T_1fc7f_row127_col0, #T_1fc7f_row176_col0, #T_1fc7f_row322_col0, #T_1fc7f_row376_col0, #T_1fc7f_row709_col1 {
#   background-color: #b9e0ed;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row9_col1, #T_1fc7f_row95_col0, #T_1fc7f_row361_col0, #T_1fc7f_row568_col0 {
#   background-color: #3c59a6;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row10_col0, #T_1fc7f_row78_col1, #T_1fc7f_row229_col0, #T_1fc7f_row269_col0, #T_1fc7f_row285_col1, #T_1fc7f_row352_col1, #T_1fc7f_row355_col1, #T_1fc7f_row662_col0, #T_1fc7f_row699_col1 {
#   background-color: #fdc374;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row10_col1, #T_1fc7f_row67_col1, #T_1fc7f_row146_col1, #T_1fc7f_row207_col1 {
#   background-color: #b6dfec;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row11_col0, #T_1fc7f_row55_col0, #T_1fc7f_row367_col0, #T_1fc7f_row477_col0, #T_1fc7f_row638_col0 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row12_col0, #T_1fc7f_row45_col0, #T_1fc7f_row257_col0, #T_1fc7f_row574_col0, #T_1fc7f_row599_col0, #T_1fc7f_row669_col0 {
#   background-color: #f3fbd4;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row12_col1, #T_1fc7f_row47_col1, #T_1fc7f_row54_col1, #T_1fc7f_row76_col1, #T_1fc7f_row121_col1, #T_1fc7f_row150_col0, #T_1fc7f_row179_col0, #T_1fc7f_row232_col0, #T_1fc7f_row278_col1, #T_1fc7f_row416_col0, #T_1fc7f_row424_col0, #T_1fc7f_row590_col1, #T_1fc7f_row627_col1, #T_1fc7f_row707_col1 {
#   background-color: #f99153;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row13_col0, #T_1fc7f_row97_col0, #T_1fc7f_row198_col0, #T_1fc7f_row300_col1, #T_1fc7f_row341_col0, #T_1fc7f_row377_col0 {
#   background-color: #eaf7e6;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row13_col1, #T_1fc7f_row40_col1, #T_1fc7f_row323_col1, #T_1fc7f_row339_col1, #T_1fc7f_row552_col1, #T_1fc7f_row607_col1, #T_1fc7f_row668_col0, #T_1fc7f_row693_col1 {
#   background-color: #feca7c;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row14_col0, #T_1fc7f_row26_col0, #T_1fc7f_row27_col1, #T_1fc7f_row103_col0, #T_1fc7f_row112_col1, #T_1fc7f_row168_col0, #T_1fc7f_row181_col0, #T_1fc7f_row328_col1, #T_1fc7f_row343_col1, #T_1fc7f_row353_col1, #T_1fc7f_row511_col1, #T_1fc7f_row518_col0, #T_1fc7f_row529_col1, #T_1fc7f_row548_col0, #T_1fc7f_row580_col1, #T_1fc7f_row587_col0, #T_1fc7f_row672_col1, #T_1fc7f_row719_col1 {
#   background-color: #fca85e;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row14_col1, #T_1fc7f_row156_col0, #T_1fc7f_row393_col0, #T_1fc7f_row463_col0, #T_1fc7f_row480_col1 {
#   background-color: #c3e5f0;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row15_col0, #T_1fc7f_row331_col1, #T_1fc7f_row382_col0, #T_1fc7f_row523_col0 {
#   background-color: #7ab2d4;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row15_col1, #T_1fc7f_row28_col1, #T_1fc7f_row89_col1, #T_1fc7f_row110_col0, #T_1fc7f_row396_col1, #T_1fc7f_row586_col1 {
#   background-color: #b30d26;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_1fc7f_row16_col0, #T_1fc7f_row210_col1, #T_1fc7f_row237_col0, #T_1fc7f_row309_col1, #T_1fc7f_row420_col0, #T_1fc7f_row427_col1, #T_1fc7f_row580_col0, #T_1fc7f_row673_col0 {
#   background-color: #fee79b;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row16_col1, #T_1fc7f_row274_col0, #T_1fc7f_row509_col0, #T_1fc7f_row577_col1, #T_1fc7f_row630_col1 {
#   background-color: #cbe9f2;
#   color: #000000;
#   font-size: 20px;
# }
# #T_1fc7f_row17_col0, #T_1fc7f_row44_col0, #T_1fc7f_row59_col0, #T_1fc7f_row278_col0, #T_1fc7f_row286_col0, #T_1fc7f_row338_col0, #T_1fc7f_row419_col1, #T_1fc7f_row443_col0, #T_1fc7f_row460_col0, #T_1fc7f_row520_col0, #T_1fc7f_row558_col1, #T_1fc7f_row595_col1 {
#   background-color

# %% [markdown]
# # 37. Which PrimaryDiagnosis has the biggest difference between maximum and minimum Expected LOS?

# %%
diff_expected_los = round(df_hosp['ReAdmissionRegistry']['ExpectedLOS'].max() - df_hosp['ReAdmissionRegistry']['ExpectedLOS'].min(),2)
print(f"Records with ExpectedLos > {diff_expected_los}:\n")
df_hosp['ReAdmissionRegistry'][(df_hosp['ReAdmissionRegistry']['ExpectedLOS'] > diff_expected_los)]

# %% [markdown]
# # 38. Mortality O:E

# %%
# table Discharges
filtered_df_hosp = df_hosp['Discharges'][(df_hosp['Discharges']['DischargeDisposition'] == 'Expired')]
observed_mortality = len(filtered_df_hosp)
sum_of_expected_mortality = df_hosp['Discharges']['ExpectedMortality'].sum()
print(f"Mortality ratio(O:E): \t {round((observed_mortality/sum_of_expected_mortality), 2)}")
# Out:
# Mortality ratio(O:E): 	 0.43

# %% [markdown]
# # 39. "Create a figure object called fig using plt.figure()
# # ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
#
#      ExpectedMortality  ReadmissionFlag  DaysToReadmission  \
# 6             0.526198              1.0                5.0
# 18            0.478003              NaN                NaN
# 31            0.774480              1.0                5.0
# 46            0.385435              NaN                NaN
# 64            0.967396              1.0                2.0
# 88            0.395238              1.0                1.0
# 95            0.824220              1.0                3.0
# 100           0.958035              1.0               14.0
# 113           0.639241              1.0                2.0
# 118           0.629358              1.0                5.0
# 140           0.460186              NaN                NaN
# 144           0.568847              1.0                5.0
# 182           0.318426              NaN                NaN
# 197           0.320295              1.0                1.0
# 201           0.082132              NaN                NaN
# 210           0.419545              NaN                NaN
# 217           0.394041              1.0                4.0
# 224           0.624283              1.0                5.0
# 233           0.487404              NaN                NaN
# 263           0.264117              1.0                5.0
# 266           0.821217              1.0                5.0
# 268           0.328102              1.0                5.0
# 288           0.209943              1.0                3.0
# 308           0.546420              1.0                3.0
# 313           0.209086              NaN                NaN
# 335           0.482830              1.0                3.0
# 344           0.308928              NaN                NaN
# 357           0.143620              NaN                NaN
# 358           0.573870              NaN                NaN
# 361           0.664635              1.0                3.0
# 371           0.401682              NaN                NaN
# 389           0.783586              1.0                7.0
# 421           0.057530              NaN                NaN
# 431           0.065651              NaN                NaN
# 441           0.182240              NaN                NaN
# 445           0.358536              1.0               10.0
# 453           0.280233              1.0               11.0
# 469           0.447190              NaN                NaN
# 473           0.206923              NaN                NaN
# 479           0.859087              NaN                NaN
# 515           0.763070              1.0                3.0
# 525           0.104853              NaN                NaN
# 542           0.808604              NaN                NaN
# 568           0.654254              NaN                NaN
# 569           0.172149              NaN                NaN
# 578           0.424688              NaN                NaN
# 626           0.461280              NaN                NaN
# 632           0.131845              NaN                NaN
# 643           0.973067              1.0                2.0
# 646           0.917408              NaN                NaN
# 647           0.188014              NaN                NaN
# 667           0.468351              NaN                NaN
# 687           0.362760              NaN                NaN
# 708           0.361812              1.0                1.0
#
#      EDVisitAfterDischargeFlag
# 6                          1.0
# 18                         NaN
# 31                         1.0
# 46                         NaN
# 64                         1.0
# 88                         1.0
# 95                         1.0
# 100                        1.0
# 113                        1.0
# 118                        1.0
# 140                        1.0
# 144                        1.0
# 182                        1.0
# 197                        1.0
# 201                        1.0
# 210                        NaN
# 217                        1.0
# 224                        1.0
# 233                        1.0
# 263                        1.0
# 266                        1.0
# 268                        1.0
# 288                        1.0
# 308                        1.0
# 313                        NaN
# 335                        1.0
# 344                        NaN
# 357                        NaN
# 358                        1.0
# 361                        1.0
# 371                        NaN
# 389                        1.0
# 421                        NaN
# 431                        1.0
# 441                        1.0
# 445                        1.0
# 453                        1.0
# 469                        NaN
# 473                        1.0
# 479                        1.0
# 515                        1.0
# 525                        NaN
# 542                        1.0
# 568                        1.0
# 569                        1.0
# 578                        1.0
# 626                        1.0
# 632                        1.0
# 643                        1.0
# 646                        NaN
# 647                        NaN
# 667                        NaN
# 687                        1.0
# 708                        1.0
